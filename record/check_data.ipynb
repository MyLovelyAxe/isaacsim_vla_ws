# %%
import numpy as np
from pathlib import Path
from glob import glob

dataset_path = Path("~/isaacsim_vla_ws/record").expanduser()
dataset_path

# %%
all_npy_files = sorted(dataset_path.glob("*.npy"))
all_npy_files

# %%
all_npy_files[0].name

# %%
npy_file = Path("20260110_091626.npy")
npy_file

# %%
loaded_npy = np.load(npy_file, allow_pickle=True).item()

# %%
loaded_npy.keys()

# %%
type(loaded_npy['joint_states_time'])

# %%
len(loaded_npy['joint_states_time'])

# %%
loaded_npy['executed_actions'][20:25]

# %%
loaded_npy['proposed_actions'][20:25]
